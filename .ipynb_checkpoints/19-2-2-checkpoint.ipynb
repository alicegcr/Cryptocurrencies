# %%
import pandas as pd

# %%
file_path = "/Users/alicetamiazzo/Desktop/Cryptocurrencies/iris.csv"
iris_df = pd.read_csv(file_path)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
new_iris_df = iris_df.drop(['class'], axis=1)
new_iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
new_iris_df = new_iris_df[['sepal_length', 'petal_length', 'sepal_width', 'petal_width']]
new_iris_df.head()
# Out:
#    sepal_length  petal_length  sepal_width  petal_width
# 0           5.1           1.4          3.5          0.2
# 1           4.9           1.4          3.0          0.2
# 2           4.7           1.3          3.2          0.2
# 3           4.6           1.5          3.1          0.2
# 4           5.0           1.4          3.6          0.2

# %%
output_file_path = "/Users/alicetamiazzo/Desktop/Cryptocurrencies/new_iris_data.csv"
new_iris_df.to_csv(output_file_path, index=False)

# %%
file_path = "/Users/alicetamiazzo/Desktop/Cryptocurrencies/shopping_data.csv"
df_shopping = pd.read_csv(file_path, encoding = 'ISO-8859-1')
df_shopping.head()
